# %%
import pandas as pd
from pathlib import Path

from data_management_von_gaudecker.config import SRC, BLD
from data_management_von_gaudecker.data_loader.data_loader import dta_loader

# %%
SRC.resolve()
# Out:
# PosixPath('/Users/felixschmitz/Library/Mobile Documents/com~apple~CloudDocs/Academia/Education/Master/Bonn/Semester1/AdvancedModules/EffectiveProgrammingPracticesForEconomists/data_management_von_gaudecker/src/data_management_von_gaudecker')

# %%
PATH = SRC / "data" / "V37" / "biobirth.dta"
raw = dta_loader(PATH)

# %%
raw["hh_id"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/data_management_von_gaudecker/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hh_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 raw['hh_id']
#
# File ~/miniconda3/envs/data_management_von_gaudecker/lib/python3.11/site-packages/pandas/core/frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~/miniconda3/envs/data_management_von_gaudecker/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'hh_id'

# %%
raw.head()
# Out:
#     cid    pid            sex gebjahr  \
# 0  19.0  101.0  [1] maennlich  1930.0
# 1  19.0  102.0   [2] weiblich  1940.0
# 2  19.0  103.0  [1] maennlich  1963.0
# 3  27.0  201.0   [2] weiblich  1926.0
# 4  27.0  202.0   [2] weiblich  1956.0
#
#                                     biovalid  \
# 0               [10] keine Geburtsbiographie
# 1              [31] Geburtsbio (mit Kindern)
# 2               [10] keine Geburtsbiographie
# 3              [31] Geburtsbio (mit Kindern)
# 4  [30] Geburtsbio (ohne Angaben zu Kindern)
#
#                                              bioinfo               bioyear  \
# 0                   [5] nomatch, only brutto (proxy)  [-2] trifft nicht zu
# 1         [2] match, bio (self-rep) + brutto (proxy)                1984.0
# 2                   [5] nomatch, only brutto (proxy)  [-2] trifft nicht zu
# 3  [1] perfect match, bio (self-rep) + brutto (pr...                1984.0
# 4                   [4] nomatch, only bio (self-rep)                1985.0
#
#                  bioage               biokids sumkids  ...  \
# 0  [-2] trifft nicht zu  [-2] trifft nicht zu     1.0  ...
# 1                  44.0                   2.0     2.0  ...
# 2  [-2] trifft nicht zu  [-2] trifft nicht zu     1.0  ...
# 3                  58.0                   2.0     2.0  ...
# 4                  29.0                   0.0     0.0  ...
#
#                kidmon11              kidmon10              kidmon12  \
# 0  [-2] trifft nicht zu  [-2] trifft nicht zu  [-2] trifft nicht zu
# 1  [-2] trifft nicht zu  [-2] trifft nicht zu  [-2] trifft nicht zu
# 2  [-2] trifft nicht zu  [-2] trifft nicht zu  [-2] trifft nicht zu
# 3  [-2] trifft nicht zu  [-2] trifft nicht zu  [-2] trifft nicht zu
# 4  [-2] trifft nicht zu  [-2] trifft nicht zu  [-2] trifft nicht zu
#
#                kidmon13              kidmon14              kidmon15  \
# 0  [-2] trifft nicht zu  [-2] trifft nicht zu  [-2] trifft nicht zu
# 1  [-2] trifft nicht zu  [-2] trifft nicht zu  [-2] trifft nicht zu
# 2  [-2] trifft nicht zu  [-2] trifft nicht zu  [-2] trifft nicht zu
# 3  [-2] trifft nicht zu  [-2] trifft nicht zu  [-2] trifft nicht zu
# 4  [-2] trifft nicht zu  [-2] trifft nicht zu  [-2] trifft nicht zu
#
#                kidmon16              kidmon17              kidmon18  \
# 0  [-2] trifft nicht zu  [-2] trifft nicht zu  [-2] trifft nicht zu
# 1  [-2] trifft nicht zu  [-2] trifft nicht zu  [-2] trifft nicht zu
# 2  [-2] trifft nicht zu  [-2] trifft nicht zu  [-2] trifft nicht zu
# 3  [-2] trifft nicht zu  [-2] trifft nicht zu  [-2] trifft nicht zu
# 4  [-2] trifft nicht zu  [-2] trifft nicht zu  [-2] trifft nicht zu
#
#                kidmon19
# 0  [-2] trifft nicht zu
# 1  [-2] trifft nicht zu
# 2  [-2] trifft nicht zu
# 3  [-2] trifft nicht zu
# 4  [-2] trifft nicht zu
#
# [5 rows x 86 columns]

# %%
raw.head().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 86 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0